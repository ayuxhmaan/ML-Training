# %%
import pandas as pd

path = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data"

column_names =['Alcohol', 'Malic acid','Ash','Alkalinity of ash','Magnesium','Total phenol','Flavanoids','Non flavanoids','Proanthocyanins','Color intensity','Hue','diluted wines','Proline']
df = pd.read_csv(path, header = None , names = column_names)

# %%
df.head()
# Out:
#    Alcohol  Malic acid   Ash  Alkalinity of ash  Magnesium  Total phenol  \
# 1    14.23        1.71  2.43               15.6        127          2.80
# 1    13.20        1.78  2.14               11.2        100          2.65
# 1    13.16        2.36  2.67               18.6        101          2.80
# 1    14.37        1.95  2.50               16.8        113          3.85
# 1    13.24        2.59  2.87               21.0        118          2.80
#
#    Flavanoids  Non flavanoids  Proanthocyanins  Color intensity   Hue  \
# 1        3.06            0.28             2.29             5.64  1.04
# 1        2.76            0.26             1.28             4.38  1.05
# 1        3.24            0.30             2.81             5.68  1.03
# 1        3.49            0.24             2.18             7.80  0.86
# 1        2.69            0.39             1.82             4.32  1.04
#
#    diluted wines  Proline
# 1           3.92     1065
# 1           3.40     1050
# ...

# %%
cols = ['Alcohol','Malic acid','Ash','Alkalinity of ash','Magnesium']

# %%
from sklearn import preprocessing
min_max_scaler_object = preprocessing.MinMaxScaler()
df = min_max_scaler_object.fit_transform(df)

# %%
df
# Out:
# array([[0.84210526, 0.1916996 , 0.57219251, ..., 0.45528455, 0.97069597,
#         0.56134094],
#        [0.57105263, 0.2055336 , 0.4171123 , ..., 0.46341463, 0.78021978,
#         0.55064194],
#        [0.56052632, 0.3201581 , 0.70053476, ..., 0.44715447, 0.6959707 ,
#         0.64693295],
#        ...,
#        [0.58947368, 0.69960474, 0.48128342, ..., 0.08943089, 0.10622711,
#         0.39728959],
#        [0.56315789, 0.36561265, 0.54010695, ..., 0.09756098, 0.12820513,
#         0.40085592],
#        [0.81578947, 0.66403162, 0.73796791, ..., 0.10569106, 0.12087912,
#         0.20114123]])

# %%
df = pd.DataFrame(df , columns = column_names)               
df
# Out:
#       Alcohol  Malic acid       Ash  Alkalinity of ash  Magnesium  \
# 0    0.842105    0.191700  0.572193           0.257732   0.619565
# 1    0.571053    0.205534  0.417112           0.030928   0.326087
# 2    0.560526    0.320158  0.700535           0.412371   0.336957
# 3    0.878947    0.239130  0.609626           0.319588   0.467391
# 4    0.581579    0.365613  0.807487           0.536082   0.521739
# ..        ...         ...       ...                ...        ...
# 173  0.705263    0.970356  0.582888           0.510309   0.271739
# 174  0.623684    0.626482  0.598930           0.639175   0.347826
# 175  0.589474    0.699605  0.481283           0.484536   0.543478
# 176  0.563158    0.365613  0.540107           0.484536   0.543478
# 177  0.815789    0.664032  0.737968           0.716495   0.282609
#
#      Total phenol  Flavanoids  Non flavanoids  Proanthocyanins  \
# 0        0.627586    0.573840        0.283019         0.593060
# ...
